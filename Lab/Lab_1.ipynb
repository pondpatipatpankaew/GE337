# %% [markdown]
# <a href="https://colab.research.google.com/github/pondpatipatpankaew/GE337/blob/main/Lab/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **การวิเคราะห์พื้นที่ให้บริการของสถานีรถไฟฟ้า ในเขตจตุจักร กรุงเทพมหานคร**

# %% [markdown]
# **1. นำเข้าข้อมูล**

# %%
# !pip install geopandas -q
# !pip install osmnx -q

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
bts = gpd.read_file("/content/BTS_Station.shp")
mrt = gpd.read_file("/content/MRT_Station.shp")
district = gpd.read_file("/content/Chatuchak.shp")

bts = bts.to_crs(epsg=32647)
mrt = mrt.to_crs(epsg=32647)
district = district.to_crs(epsg=32647)

# %%
print("BTS CRS:", bts.crs)
print("MRT CRS:", mrt.crs)
print("District CRS:", district.crs)
# Out:
# BTS CRS: EPSG:32647
# MRT CRS: EPSG:32647
# District CRS: EPSG:32647

# %%
stations = bts._append(mrt, ignore_index=True)

# %%
ax = district.plot(color="white", edgecolor="black", figsize=(8,8))
stations.plot(ax=ax, color="red")
plt.show()

# %% [markdown]
# **2. กำหนดระยะ Buffer**

# %%
stations["buffer"] = stations.geometry.buffer(1000)
buffers = stations.set_geometry("buffer")

# %%
ax = district.plot(color="white", edgecolor="black", figsize=(8,8))
buffers.plot(ax=ax, color="blue", alpha=0.3)
stations.plot(ax=ax, color="red", markersize=10)

plt.title("1 km Service Area of BTS & MRT Stations")
plt.show()

# %% [markdown]
# **3. ทำ Spatial Join**

# %%
import geopandas as gpd
joined = gpd.sjoin(stations, district, how="inner", predicate="within")

# %%
print("Number of stations in district:", len(joined))
for station in joined["name"]:
    print(station)
# Out:
# Number of stations in district: 14
# สถานีหมอชิต
# สถานีห้าแยกลาดพร้าว
# สถานีพหลโยธิน 24
# สถานีรัชโยธิน
# สถานีมหาวิทยาลัยเกษตรศาสตร์
# สถานีเสนานิคม
# สถานีบางบัว
# สถานีกรมป่าไม้
# สถานีบางซื่อ
# สถานีสวนจตุจักร
# สถานีลาดพร้าว
# สถานีกำแพงเพชร
# สถานีพหลโยธิน
# สถานีลาดพร้าว

# %% [markdown]
# **4. คำนวณพื้นที่ครอบคลุม**

# %%
buffer_union = buffers.dissolve()
affected_area = gpd.overlay(district, buffer_union, how="intersection")
# พื้นที่เขตทั้งหมด
district_area = district.area.iloc[0]

# พื้นที่ที่ถูกครอบคลุม
covered_area = affected_area.area.iloc[0]

# %%
district_km2 = district_area / 1_000_000
covered_km2 = covered_area / 1_000_000

# %%
percentage = (covered_area / district_area) * 100

# %%
print(f"Total district area: {district_km2:.2f} sq.km")
print(f"Covered area by 5 km buffer: {covered_km2:.2f} sq.km")
print(f"Coverage percentage: {percentage:.2f}%")
# Out:
# Total district area: 32.66 sq.km
# Covered area by 5 km buffer: 17.65 sq.km
# Coverage percentage: 54.04%

# %% [markdown]
# **5. แสดงผลแบบ Interactive Map**

# %%
# !pip install folium -q

import folium
import geopandas as gpd

# %%
# รวม buffer ทั้งหมด
buffer_union = buffers.unary_union

# สร้าง GeoDataFrame ใหม่
buffer_union_gdf = gpd.GeoDataFrame(
    geometry=[buffer_union],
    crs=buffers.crs
)
# Out:
# /tmp/ipython-input-4031596385.py:2: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   buffer_union = buffers.unary_union

# %%
center_point = district.geometry.centroid.iloc[0]

# แปลง centroid เป็น EPSG:4326
center_point = gpd.GeoSeries(
    [center_point], crs=district.crs
).to_crs(epsg=4326)

center = [
    center_point.geometry.y.iloc[0],
    center_point.geometry.x.iloc[0]
]

# สร้างแผนที่
m = folium.Map(
    location=center,
    zoom_start=13,
    tiles="cartodbpositron"
)

# %%
district_4326 = district.to_crs(epsg=4326)
stations_4326 = stations.to_crs(epsg=4326)
buffer_union_4326 = buffer_union_gdf.to_crs(epsg=4326)

# %%
folium.GeoJson(
    district_4326,
    name="District Boundary",
    style_function=lambda feature: {
        "fillColor": "none",
        "color": "black",
        "weight": 2,
    },
    tooltip=folium.GeoJsonTooltip(
        fields=["dname"],
        aliases=["District:"]
    )
).add_to(m)

# %%
folium.GeoJson(
    buffer_union_4326,
    name="5 km Service Area",
    style_function=lambda feature: {
        "fillColor": "blue",
        "color": "blue",
        "weight": 2,
        "fillOpacity": 0.3,
    },
    tooltip="5 km Service Area"
).add_to(m)

# %%
for _, row in stations_4326.iterrows():
    folium.Marker(
        location=[row.geometry.y, row.geometry.x],
        popup=row["name"],
        tooltip=row["name"],
        icon=folium.Icon(color="red", icon="train", prefix="fa")
    ).add_to(m)

# %%
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_437db2dc3255b5dd0e8e8bad17a251f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_437db2dc3255b5dd0e8e8bad17a251f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_437db2dc3255b5dd0e8e8bad17a251f9 = L.map(
#                 &quot;map_437db2dc3255b5dd0e8e8bad17a251f9&quot;,
#                 {
#                     center: [13.82651995554886, 100.5651407250344],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3478e1595f5ef8fba481855faeb4582 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b3478e1595f5ef8fba481855faeb4582.addTo(map_437db2dc3255b5dd0e8e8bad17a251f9);
#
#
#         function geo_json_3cb1d0a71d6b608e49df440ed8686383_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;none&quot;, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_3cb1d0a71d6b608e49df440ed8686383_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_3cb1d0a71d6b608e49df440ed8686383 = L.geoJson(null, {
#                 onEachFeature: geo_json_3cb1d0a71d6b608e49df440ed8686383_onEachFeature,
#
#                 style: geo_json_3cb1d0a71d6b608e49df440ed8686383_styler,
#             ...{
# }
#         });
#
#         function geo_json_3cb1d0a71d6b608e49df440ed8686383_add (data) {
#             geo_json_3cb1d0a71d6b608e49df440ed8686383
#                 .addData(data);
#         }
#             geo_json_3cb1d0a71d6b608e49df440ed8686383_add({&quot;bbox&quot;: [100.53696052372761, 13.794604321478484, 100.59109892721332, 13.858954130166298], &quot;features&quot;: [{&quot;bbox&quot;: [100.53696052372761, 13.794604321478484, 100.59109892721332, 13.858954130166298], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.58669164213444, 13.858329955462613], [100.58671396080685, 13.85829591431718], [100.58676014878691, 13.858200705168708], [100.58682472637314, 13.858003688026738], [100.5869304693298, 13.85782335191278], [100.58699720288847, 13.857688464070447], [100.5870612295442, 13.857580710565786], [100.58712588076371, 13.857479732352603], [100.58721452352576, 13.857335662965932], [100.58725739537846, 13.857263072794145], [100.58729911898772, 13.857191620108445], [100.58733098238223, 13.857115711790161], [100.58739242771368, 13.856968429202578], [100.58743282586704, 13.856872127779086], [100.5874622769964, 13.856781546650957], [100.58750131902194, 13.85665587712952], [100.58752732420243, 13.856568707867648], [100.5875579110577, 13.856389988710646], [100.58755629433935, 13.856322206594045], [100.58755802374547, 13.856236324810748], [100.58756159800339, 13.856081508414766], [100.58756349121956, 13.85593461201026], [100.5875644020543, 13.855643097629464], [100.58756141395433, 13.855543687730266], [100.58755801439834, 13.855298526409717], [100.58755825230973, 13.855078198816205], [100.58755562793101, 13.854947149879704], [100.58756451542602, 13.85472337666801], [100.58757068879147, 13.854525608113812], [100.58757744041908, 13.854327835807835], [100.58757976348498, 13.854244209641834], [100.58758414839295, 13.854038543587658], [100.58758550756994, 13.853727818246712], [100.58758248222917, 13.853112054707806], [100.58763408722487, 13.85304844674238], [100.58764622365163, 13.852962497461824], [100.58765036830792, 13.852806547599904], [100.58765096463276, 13.852724062669834], [100.58765728112569, 13.85263250151089], [100.58765853212446, 13.852561310951353], [100.58765861159515, 13.852487868509852], [100.58766393273531, 13.852420041389093], [100.58767552957629, 13.852339744914289], [100.58770576808492, 13.852194924470323], [100.5877214350393, 13.852117991127168], [100.58775235151151, 13.851987854731446], [100.58777156404128, 13.851922197319707], [100.58783331774578, 13.851735367

# %% [markdown]
# ## **ความแตกต่างระหว่าง Spatial Join และ Attribute Join**
#
# *   **Spatial Join** คือการเชื่อมข้อมูลโดยอาศัยความสัมพันธ์เชิงพื้นที่ของ geometry เช่น within , contains , intersects
# เช่น นับจำนวนสถานีที่อยู่ภายในเขตจตุจักร
#
# * **Attribute Join** คือการเชื่อมข้อมูลโดยใช้ค่าคอลัมน์ที่เหมือนกัน เช่น รหัสของพื้นที่ ไม่ได้พิจารณาตำแหน่งทางภูมิศาสตร์

# %% [markdown]
# ## **ทำไมเราต้องแปลงระบบพิกัดก่อนใช้ buffer() ใน GeoPandas?**
#
# เพราะ buffer() คำนวณระยะทางตามหน่วยของ CRS ถ้าใช้ EPSG:4326 หน่วยจะเป็นองศา จะทำให้ buffer มีขนาดผิดพลาด จึงต้องแปลงเป็น CRS (เช่น EPSG:32647) ที่มีหน่วยเป็นเมตรก่อน เพื่อให้ buffer ระยะ 5,000 เมตร ถูกต้องจริง

# %% [markdown]
# ##**หากต้องการวิเคราะห์ระยะ 10 กิโลเมตร แทน 5 กิโลเมตร**
# ให้แก้ที่ขั้นตอนสร้าง buffer
#
# จากเดิม
#
# buffers = stations.buffer(5000)
#
#
# เปลี่ยนเป็น
#
# buffers = stations.buffer(10000)
#
#
# เพราะ 10 กิโลเมตร = 10,000 เมตร

# %% [markdown]
# ## **วิธีที่เหมาะสมที่สุดในการแสดงผล Interactive Map**
#
#
# วิธีที่เหมาะสมที่สุดในการแสดงผล Interactive Map คืออะไร เพราะเหตุใด?
#
# การใช้ Folium เหมาะสมที่สุด เพราะ
#
# * รองรับ Interactive Map
#
# * สามารถ zoom, pan, เปิด-ปิด layer ได้
#
# * แสดง popup และ tooltip ได้
#
# * แปลง GeoDataFrame เป็น GeoJSON ได้โดยตรง
#
# ทำให้ผู้ใช้งานสามารถสำรวจข้อมูลเชิงพื้นที่ได้สะดวกและเข้าใจง่าย

# %% [markdown]
# ## **หาก Buffer มีขนาดไม่ถูกต้อง อาจเกิดจากอะไร และแก้ไขอย่างไร**
# สาเหตุที่เป็นไปได้
#
# * ใช้ CRS แบบ Geographic
#
# * ไม่ได้แปลง CRS ก่อน buffer
#
# * ใช้หน่วยผิด (เช่น ใส่ 5 แทน 5000)
#
# * CRS ของ layer ไม่ตรงกัน
#
# วิธีแก้
#
# * ตรวจสอบ CRS
# * แปลงเป็น Projected CRS ก่อน buffer
# * ใช้หน่วยเป็นเมตร (เช่น 5000 = 5 km)
