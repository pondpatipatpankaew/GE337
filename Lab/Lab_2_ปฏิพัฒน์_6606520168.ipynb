# %% [markdown]
# <a href="https://colab.research.google.com/github/pondpatipatpankaew/GE337/blob/main/Lab/Lab_2_%E0%B8%9B%E0%B8%8F%E0%B8%B4%E0%B8%9E%E0%B8%B1%E0%B8%92%E0%B8%99%E0%B9%8C_6606520168.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **1. INSTALL & IMPORT**

# %%
# !pip install geopandas rasterio folium geemap earthengine-api shapely pyproj fiona rtree -q

import geopandas as gpd
import rasterio
from rasterio.mask import mask
from rasterio.plot import plotting_extent
import matplotlib.pyplot as plt
import numpy as np
import folium
import ee
import geemap
from google.colab import drive
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 37.1 MB/s eta 0:00:00

# %% [markdown]
# ## **2. CONNECT GOOGLE DRIVE**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Mounted at /content/drive

# %% [markdown]
# ## **3. LOAD VECTOR DATA**

# %%
# --- 3.1 Load Province Boundary ---
shp_path = '/content/drive/MyDrive/Labdata/Lab Data/lopburi.shp'
lopburi = gpd.read_file(shp_path)

print("Vector CRS:", lopburi.crs)
print("Number of features:", len(lopburi))


# --- 3.2 Load Weather Stations ---
station_path = '/content/drive/MyDrive/Labdata/Lab Data/TMD_ALL_Stations.shp'
stations = gpd.read_file(station_path)

stations = stations.to_crs(lopburi.crs)

stations_lopburi = gpd.sjoin(stations, lopburi, predicate="within")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Vector CRS: EPSG:4326
# Number of features: 1

# %% [markdown]
# ## **4. VISUALIZE VECTOR DATA**

# %%
fig, ax = plt.subplots(figsize=(6,6))
lopburi.plot(ax=ax, edgecolor='black', facecolor='none')
stations_lopburi.plot(ax=ax, color='red', markersize=20)
plt.title("Weather Stations in Lopburi")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
center = lopburi.geometry.centroid.iloc[0]

m = folium.Map(location=[center.y, center.x], zoom_start=8)

folium.GeoJson(lopburi).add_to(m)

for _, row in stations_lopburi.iterrows():
    folium.Marker(
        location=[row.geometry.y, row.geometry.x]
    ).add_to(m)

m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /tmp/ipython-input-4280195466.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = lopburi.geometry.centroid.iloc[0]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe378bd206487b1642e02a3df4872d87 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe378bd206487b1642e02a3df4872d87&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe378bd206487b1642e02a3df4872d87 = L.map(
#                 &quot;map_fe378bd206487b1642e02a3df4872d87&quot;,
#                 {
#                     center: [15.094660497438317, 100.89950134305592],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a17a62dec789d54dd7ec114b7fb128a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4a17a62dec789d54dd7ec114b7fb128a.addTo(map_fe378bd206487b1642e02a3df4872d87);
#
#
#
#         function geo_json_19314203e70ead58a20b93ad3db1582e_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_19314203e70ead58a20b93ad3db1582e = L.geoJson(null, {
#                 onEachFeature: geo_json_19314203e70ead58a20b93ad3db1582e_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_19314203e70ead58a20b93ad3db1582e_add (data) {
#             geo_json_19314203e70ead58a20b93ad3db1582e
#                 .addData(data);
#         }
#             geo_json_19314203e70ead58a20b93ad3db1582e_add({&quot;bbox&quot;: [100.42001722263005, 14.655216095735458, 101.41448568506836, 15.581223147714729], &quot;features&quot;: [{&quot;bbox&quot;: [100.42001722263005, 14.655216095735458, 101.41448568506836, 15.581223147714729], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[101.3709446596968, 15.577429680650672], [101.37059468283456, 15.574698352750001], [101.37065660685016, 15.57242787276715], [101.37098413234699, 15.57015564102364], [101.37114192350349, 15.568318885958659], [101.37147238479996, 15.566509614711574], [101.37188794834444, 15.564192400562854], [101.37237295512026, 15.56158310749338], [101.37279104603269, 15.559946809072885], [101.3736258951827, 15.557524575000857], [101.373759514712, 15.555971529432103], [101.37353180600378, 15.552214657268687], [101.37355300490769, 15.550607464928682], [101.37361333110616, 15.548960331194605], [101.3733330207793, 15.54726946368393], [101.37318650941236, 15.54617225016778], [101.3732569326092, 15.54540588232576], [101.37364066307585, 15.544483649257714], [101.37379291198594, 15.543589884526714], [101.3738908153864, 15.542373736514588], [101.37391595343522, 15.540703261172482], [101.37403388886871, 15.53945981038072], [101.37435075516048, 15.538192755300628], [101.37472643067143, 15.536262180086005], [101.37484831991401, 15.535360823931832], [101.37484048138954, 15.534676597071588], [101.37478050919637, 15.533306288417236], [101.37453431231202, 15.531082048371031], [101.37442228191502, 15.529027987414427], [101.37440953576936, 15.527914678458304], [101.3745280821843, 15.526671183912676], [101.37473602698248, 15.525555500899731], [101.37504601696399, 15.523688873392828], [101.37556340534105, 15.522083111437224], [101.37558478910933, 15.522017383778188], [101.37602724805954, 15.520681224287086], [101.37732358419709, 15.518139981077537], [101.37831551896502, 15.516074032512364], [101.37947218884466, 15.512935751385218], [101.38006405054612, 15.51061663848197], [101.38043167239478, 15.508042470378095], [101.38067706549108, 15.506284958841022], [101.38097341677118, 15.505211210194265], [101.38139813254134, 15.503706981739246], [101.38178452138024, 15.502718072940512], [101.3818883875458, 15.502534044101628], [101.3823092695804, 15.50130538614767], [101.38280284674333, 15.499813921435111], [101.38308342010492, 15.498284122201543], [101.38313507915531, 15.497251457591654], [101.38325040351735, 15.496136734487783], [101.38374585660179, 15.494810138129612], [101.38444150373512, 15.492409753636778], [101.38512969342028, 15.489307008403863], [101.38560572232002, 15.486288995803688], [101.3858401094802, 15.482614109699977], [101.38592597779099, 15.47898145493549], [101.38598827560668, 15.477000085320553], [101.38608087248252, 15.47390376290778], [101.38584867923582, 15.470356978249214], [101.38538531926118, 15.467060016167215], [101.3843968274762, 15.462490371076456], [101.38220577157995, 15.455085609832803], [101.38172126326023, 15.453646482694646], [101.38097663492543, 15.451756184674364], [101.38039245162605, 15.44908045282087], [101.3799345628228, 15.446196694661687], [101.3793376939114, 15.442405347658417], [101.37881345809177, 15.43931677341708], [101.37861985599694, 15.437296322310775], [101.37821867388764, 15.43564961566569], [101.37794011264016, 15.433631221178663], [101.377867997

# %% [markdown]
# ## **5. LOAD RASTER DATA**

# %%
raster_path = '/content/drive/MyDrive/Labdata/Lab Data/Lopburi.tif'
src = rasterio.open(raster_path)

print("CRS:", src.crs)
print("Resolution:", src.res)
print("Width x Height:", src.width, "x", src.height)
print("Number of Bands:", src.count)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# CRS: EPSG:4326
# Resolution: (0.0006180181576575864, 0.0005961566358528606)
# Width x Height: 2481 x 2501
# Number of Bands: 12

# %% [markdown]
# ## **6. TRUE COLOR COMPOSITE**

# %%
red = src.read(4)
green = src.read(3)
blue = src.read(2)

rgb = np.dstack((red, green, blue)).astype(float)

p2, p98 = np.percentile(rgb, (2, 98))
rgb_stretch = np.clip((rgb - p2) / (p98 - p2), 0, 1)

plt.figure(figsize=(6,6))
plt.imshow(rgb_stretch)
plt.title("True Color Image")
plt.axis("off")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## **7. CLIP RASTER TO PROVINCE**

# %%
lopburi_geom = lopburi.geometry.values

clipped_img, clipped_transform = mask(src, lopburi_geom, crop=True)

# Show clipped true color
red = clipped_img[3].astype(float)
green = clipped_img[2].astype(float)
blue = clipped_img[1].astype(float)

rgb = np.dstack((red, green, blue))
p2, p98 = np.percentile(rgb, (2, 98))
rgb_stretch = np.clip((rgb - p2) / (p98 - p2), 0, 1)

plt.figure(figsize=(6,6))
plt.imshow(rgb_stretch)
plt.title("Lopburi True Color")
plt.axis("off")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## **8. CALCULATE NDVI**

# %%
nir = clipped_img[7].astype(float)
red = clipped_img[3].astype(float)

ndvi = np.where(
    (nir + red) == 0,
    np.nan,
    (nir - red) / (nir + red)
)

plt.figure(figsize=(6,6))
plt.imshow(ndvi, cmap='RdYlGn')
plt.colorbar(label="NDVI")
plt.title("NDVI Lopburi")
plt.axis("off")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /tmp/ipython-input-1435389711.py:7: RuntimeWarning: invalid value encountered in divide
#   (nir - red) / (nir + red)

# %% [markdown]
# ## **9. OVERLAY NDVI + STATIONS**

# %%
extent = plotting_extent(ndvi, clipped_transform)

fig, ax = plt.subplots(figsize=(6,6))

ndvi_plot = ax.imshow(ndvi, cmap='RdYlGn', extent=extent)
lopburi.boundary.plot(ax=ax, color='black')
stations_lopburi.plot(ax=ax, color='blue', markersize=30)

plt.colorbar(ndvi_plot, ax=ax, label="NDVI")
plt.title("NDVI with Weather Stations")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## **10. EXTRACT NDVI AT STATIONS**

# %%
import rasterio

ndvi_values = []

for idx, row in stations_lopburi.iterrows():
    x, y = row.geometry.x, row.geometry.y
    r, c = rasterio.transform.rowcol(clipped_transform, x, y)

    if 0 <= r < ndvi.shape[0] and 0 <= c < ndvi.shape[1]:
        ndvi_values.append(ndvi[r, c])
    else:
        ndvi_values.append(np.nan)

stations_lopburi["NDVI"] = ndvi_values
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## **11. STATISTICAL ANALYSIS**

# %%
plt.figure(figsize=(6,4))
plt.bar(stations_lopburi.index.astype(str),
        stations_lopburi["NDVI"])

plt.xlabel("Station")
plt.ylabel("NDVI")
plt.title("NDVI Value at Each Station")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## **12. FINAL THEMATIC MAP**

# %%
fig, ax = plt.subplots(figsize=(6,6))

ndvi_plot = ax.imshow(ndvi, cmap='RdYlGn', extent=extent)
lopburi.boundary.plot(ax=ax, color='black')

stations_lopburi.plot(
    ax=ax,
    column="NDVI",
    cmap="coolwarm",
    legend=True,
    markersize=60
)

plt.title("Stations Colored by NDVI")
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## **คำถามท้าย Lab**

# %% [markdown]
# # **1. ข้อดีและข้อเสียของการใช้ Matplotlib และ Folium ในการแสดงผลข้อมูลเชิงพื้นที่คืออะไร?**
# **Matplotlib**
# ข้อดี : เหมาะกับการวิเคราะห์เชิงสถิติ ควบคุมรูปแบบกราฟได้ละเอียด แสดง raster ได้ดี
#
# ข้อเสีย : ไม่เป็น Interactive ซูม/คลิกดูข้อมูลไม่ได้
#
# **Folium**
# ข้อดี : เป็น Interactive เหมาะกับการนำเสนอแผนที่
#
# ข้อเสีย : วิเคราะห์เชิงลึกยาก และจัดการ raster ขนาดใหญ่ไม่สะดวก

# %% [markdown]
# # **2. ทำไมเราต้องใช้ Masking และ Clipping ในการวิเคราะห์ข้อมูลภาพถ่ายดาวเทียม?**
# เพื่อจำกัดข้อมูลให้อยู่เฉพาะพื้นที่ศึกษา ช่วยลดขนาดข้อมูล เพิ่มความแม่นยำ และป้องกันผลกระทบจากข้อมูลนอกพื้นที่ที่สนใจ

# %% [markdown]
# # **3. ค่า NDVI บ่งบอกถึงอะไร? และสามารถใช้ NDVI ในการวิเคราะห์อะไรได้บ้าง?**
# NDVI ใช้วัดความหนาแน่นและสุขภาพของพืชพรรณ
# สามารถใช้วิเคราะห์สุขภาพพืช ปริมาณพื้นที่สีเขียว การเปลี่ยนแปลงป่าไม้ และภัยแล้ง

# %% [markdown]
# ## **4. การแปลงค่าพิกัด (CRS) มีความสำคัญอย่างไรในการทำงานกับข้อมูลเวกเตอร์และแรสเตอร์?**
# CRS ต้องตรงกันเพื่อให้ข้อมูลเวกเตอร์และแรสเตอร์ซ้อนทับกันได้อย่างถูกต้อง หากไม่ตรงกันจะทำให้ตำแหน่งผิดพลาดและวิเคราะห์คลาดเคลื่อน

# %% [markdown]
# ## **5. หากต้องการวิเคราะห์ข้อมูลภาพถ่ายดาวเทียมในช่วงเวลาต่าง ๆ (Time Series) ควรทำอย่างไร?**
# ใช้ภาพหลายช่วงเวลา คำนวณดัชนี เช่น NDVI ในแต่ละช่วง แล้วเปรียบเทียบแนวโน้มการเปลี่ยนแปลงตามเวลา
